# %% [markdown]
# # PG Bookshelves
# Since the subject tags are very messy, I am exploring what are called bookshelves, which might be more carefully curated.
#
# See [here](http://www.gutenberg.org/wiki/Category:Bookshelf)
#
# ### Getting the data
# What I did is to scrape the PG wiki, see `data/bookshelves/`

# %%
import numpy as np
import pandas as pd
import glob
import lxml.html

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
BS_paths = glob.glob("../data/bookshelves/*Bookshelf*")
BS = [path.split("/")[-1] for path in BS_paths]

# %%
BS_dict = {}
for path in BS_paths:
    bs = path.split("/")[-1]
    BS_dict[bs] = []
    with open(path, "r") as foo:
        dom = lxml.html.fromstring(foo.read())
        # select the url in href for all a tags(links)
        for link in dom.xpath('//a/@href'):
            # links to ebooks that are not searches
            if link.find("ebooks")>-1 and link.find("search")==-1:
                PGid = "PG"+link.split("/")[-1]
                BS_dict[bs].append(PGid)

    # delete empty BSs
    if len(BS_dict[bs])==0:
        del BS_dict[bs]
    
# recompose list of BSs
BS = list(BS_dict.keys())

# list of unique PGids
PGids = list(set(np.concatenate(list(BS_dict.values()))))

# %%
# put in a DataFrame
df = pd.DataFrame(index = PGids, columns = BS)
for k,v in BS_dict.items():
    df.loc[v, k] = True

# %% [markdown]
# At the moment saving the BS df in `../data/`

# %%
df.to_pickle("../data/bookshelves.p")

# %% [markdown]
# ### Bookshelves are almost non-overlapping

# %%
# Bookshelves with at least 100 books
sdf = df.loc[:, df.sum()>100]
sdf = sdf.loc[sdf.sum(axis=1).dropna().index]

# %%
# overlaps are small
ratios = []
from itertools import combinations
for s1, s2 in combinations(sdf.columns, 2):
    l1 = len(BS_dict[s1])
    l2 = len(BS_dict[s2])
    l3 = len(np.intersect1d(BS_dict[s1], BS_dict[s2]))
    intratio = l3/min(l1, l2)
    ratios.append([intratio, s1, s2])
intersetions_df = pd.DataFrame(data=ratios, columns = ["intersection", "bs1", "bs2"])

# %%
(intersetions_df.intersection<0.05).mean()
# Out:
# 0.96617336152219868

# %% [markdown]
# That is, with probability 97% two BS have less than 5% of their books in common

# %%
intersetions_df.sort_values(by="intersection", ascending=False).head(n=25)
# Out:
#      intersection                                               bs1  \
# 724      1.000000                          Banned_Books_(Bookshelf)
# 539      0.939655                                Animal_(Bookshelf)
# 108      0.836935      Bestsellers,_American,_1895-1923_(Bookshelf)
# 229      0.362832                         United_States_(Bookshelf)
# 312      0.151786                   Classical_Antiquity_(Bookshelf)
# 869      0.134454                           Movie_Books_(Bookshelf)
# 880      0.132184  Banned_Books_from_Anne_Haight's_list_(Bookshelf)
# 725      0.132184                          Banned_Books_(Bookshelf)
# 192      0.109244                    Historical_Fiction_(Bookshelf)
# 732      0.109195                          Banned_Books_(Bookshelf)
# 887      0.109195  Banned_Books_from_Anne_Haight's_list_(Bookshelf)
# 897      0.107143              Best_Books_Ever_Listings_(Bookshelf)
# 30       0.100840                       Science_Fiction_(Bookshelf)
# 144      0.098214                                 Opera_(Bookshelf)
# 154      0.098214                                 Opera_(Bookshelf)
# 605      0.086614                               Cookery_(Bookshelf)
# 365      0.085106                 Children's_Literature_(Bookshelf)
# 234      0.079646                         United_States_(Bookshelf)
# 379      0.078616                 Children's_Literature_(Bookshelf)
# 181      0.076696                    Historical_Fiction_(Bookshelf)
# 711      0.070312                            Philosophy_(Bookshelf)
# 113      0.067227      Bestsellers,_American,_1895-1923_(Bookshelf)
# 797      0.067227      Bestsellers,_American,_1900-1923_(Bookshelf)
# 293      0.062500                   Classical_Antiquity_(Bookshelf)
# 684      0.058282                    Children's_Fiction_(Bookshelf)
#
#                                                   bs2
# 724  Banned_Books_from_Anne_Haight's_list_(Bookshelf)
# 539                  Animals-Wild_(Bookshelf)-Mammals
# 108      Bestsellers,_American,_1900-1923_(Bookshelf)
# 229                    Children's_History_(Bookshelf)
# 312                      Harvard_Classics_(Bookshelf)
# 869              Best_Books_Ever_Listings_(Bookshelf)
# 880              Best_Books_Ever_Listings_(Bookshelf)
# 725              Best_Books_Ever_Listings_(Bookshelf)
# 192                           Movie_Books_(Bookshelf)
# 732                      Harvard_Classics_(Bookshelf)
# 887                      Harvard_Classics_(Bookshelf)
# 897                      Harvard_Classics_(Bookshelf)
# 30                            Movie_Books_(Bookshelf)
# 144                          Banned_Books_(Bookshelf)
# 154  Banned_Books_from_Anne_Haight's_list_(Bookshelf)
# 605                            Technology_(Bookshelf)
# 365             Short_Stories_(Bookshelf)_Authors_A-E
# 234                          US_Civil_War_(Bookshelf)
# 379                Children's_Book_Series_(Bookshelf)
# 181                    Children's_Fiction_(Bookshelf)
# 711                      Harvard_Classics_(Bookshelf)
# 113                           Movie_Books_(Bookshelf)
# 797                           Movie_Books_(Bookshelf)
# 293                            Philosophy_(Bookshelf)
# 684                          US_Civil_War_(Bookshelf)
